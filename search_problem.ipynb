# %%
import pandas as pd
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/news/data/News_Category_Dataset_v3.json', lines=True)

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
len(df)
# Out:
# 209527

# %%
df.columns
# Out:
# Index(['link', 'headline', 'category', 'short_description', 'authors', 'date'], dtype='object')

# %%
def _clean_text(text):
    if isinstance(text, str):
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'[^\w\s.,!?\'"-]', '', text)
        text = text.strip()
        if not text:
            return 'no data'
        return text
    return 'no data'

search_columns = ['headline', 'short_description', 'authors']
for col in search_columns:
    df[col] = df[col].apply(_clean_text)

# %%
df.groupby('category').count()['link'].sort_values(ascending=False)
# Out:
# category
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# COLLEGE            1144
# LATINO VOICES      1130
# CULTURE & ARTS     1074
# EDUCATION          1014
# Name: link, dtype: int64

# %% [markdown]
# ## BM25 search

# %%
# %%capture
# !pip install bm25s[full]

# %%
import bm25s
import Stemmer
import numpy as np
from typing import List, Optional, Dict
from operator import itemgetter
from datetime import datetime

# %%
class BM25Retriever:
    def __init__(self, df: pd.DataFrame):
        self.data = df
        self.stemmer = Stemmer.Stemmer("english")
        self.retrievers = {}
        self.search_columns = ['headline', 'short_description', 'authors']


    def index(self):
        self.corpus = {col: self.data[col].fillna('').tolist() for col in self.search_columns}

        for col, docs in self.corpus.items():
            tokens = bm25s.tokenize(docs, stopwords="en", stemmer=self.stemmer)
            retriever = bm25s.BM25()
            retriever.index(tokens)
            self.retrievers[col] = retriever

    def save(self, path: str):
        for col, retriever in self.retrievers.items():
            retriever.save(f"{path}_{col}", corpus=self.corpus[col])

    def load(self, path: str):
        for col in self.search_columns:
            self.retrievers[col] = bm25s.BM25.load(f"{path}_{col}", load_corpus=True)

    def search(self, query: str, k: int = 5, category: Optional[str] = None, not_older_than: Optional[datetime] = None):
        query_tokens = bm25s.tokenize(query, stemmer=self.stemmer)
        matches = []
        for col, retriever in self.retrievers.items():
            results, scores = retriever.retrieve(query_tokens, k=k)
            for i in range(results.shape[1]):
                id, score = results[0, i]['id'], scores[0, i]
                if score > 0:
                    matches.append({
                        'id' : id,
                        'score': score,
                        'matched_field': col
                    })
        if matches:
            scores = np.array([m['score'] for m in matches])
            mean_score = np.mean(scores)
            std_score = np.std(scores) if np.std(scores) > 0 else 1  # Avoid division by zero

            for m in matches:
                m['score'] = 1 / (1 + np.exp(-((m['score'] - mean_score) / std_score)))

        filtered_results = []
        for m in matches:
            row = self.data.iloc[m['id']]
            filtered_results.append({
                'link': row['link'],
                'headline': row['headline'],
                'category': row['category'],
                'short_description': row['short_description'],
                'authors': row['authors'],
                'date': row['date'],
                'score': m['score'],
                'matched_fields': m['matched_field']
            })
        if category:
            filtered_results = [c for c in filtered_results if c['category'] in category]
        if not_older_than:
            filtered_results = [c for c in filtered_results if c['date'] >= not_older_than]
        filtered_results = sorted(filtered_results, key=itemgetter('score'), reverse=True)

        return filtered_results

# %%
RETRIVERS_PATH = '/content/drive/MyDrive/Colab Notebooks/news/retrivers/'
lexical = BM25Retriever(df)
lexical.index()
lexical.save(RETRIVERS_PATH)
# Out:
# Split strings:   0%|          | 0/209527 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# DEBUG:bm25s:Building index from IDs objects
# BM25S Count Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# BM25S Compute Scores:   0%|          | 0/209527 [00:00<?, ?it/s]
# Split strings:   0%|          | 0/209527 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# DEBUG:bm25s:Building index from IDs objects
# BM25S Count Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# BM25S Compute Scores:   0%|          | 0/209527 [00:00<?, ?it/s]
# Split strings:   0%|          | 0/209527 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# DEBUG:bm25s:Building index from IDs objects
# BM25S Count Tokens:   0%|          | 0/209527 [00:00<?, ?it/s]
# BM25S Compute Scores:   0%|          | 0/209527 [00:00<?, ?it/s]
# Finding newlines for mmindex:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# Finding newlines for mmindex:   0%|          | 0.00/29.0M [00:00<?, ?B/s]
# Finding newlines for mmindex:   0%|          | 0.00/11.8M [00:00<?, ?B/s]

# %%
lexical = BM25Retriever(df)
lexical.load(RETRIVERS_PATH)

# %%
lexical.search("Woman Who Called Cops On Black Bird-Watcher", k=3, not_older_than=datetime(2017,1,1))
# Out:
# Split strings:   0%|          | 0/1 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'link': 'https://www.huffpost.com/entry/amy-cooper-loses-discrimination-lawsuit-franklin-templeton_n_632c6463e4b09d8701bd227e',
#   'headline': 'Woman Who Called Cops On Black Bird-Watcher Loses Lawsuit Against Ex-Employer',
#   'category': 'U.S. NEWS',
#   'short_description': 'Amy Cooper accused investment firm Franklin Templeton of unfairly firing her and branding her a racist after video of the Central Park encounter went viral.',
#   'authors': 'Nina Golgowski',
#   'date': Timestamp('2022-09-22 00:00:00'),
#   'score': 0.917582910338135,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffpost.com/entry/trevor-noah-second-amendment-is-not-intended-for-black-people_n_5bfe1f02e4b0f43bf2662986',
#   'headline': "Trevor Noah 'The Second Amendment Is Not Intended For Black People'",
#   'category': 'COMEDY',
#   'short_description': 'Cops are called into a situation, they see a black person and then immediately they shoot.',
#   'authors': 'Carla Baranauckas',
#   'date': Timestamp('2018-11-28 00:00:00'),
#   'score': 0.6171525894454177,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/cookout-after-cops-called-over-black-bbq_us_5af86368e4b00d7e4c1b9caf',
#   'headline': 'Massive Cookout Thrown In Park Where Cops Were Called On Black Family BBQ',
#   'category': 'BLACK VOICES',
#   'short_description': 'How Black Oakland responds to a white lady calling the cops on Black folks BBQing."',
#   'authors': 'Nina Golgowski',
#   'date': Timestamp('2018-05-13 00:00:00'),
#   'score': 0.6144570577983236,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffpost.com/entry/sonic-snake_n_6295a660e4b05cfc269e2615',
#   'headline': 'Sonic Workers Find An Absolute Nightmare Lurking Just Behind The Fry Machine',
#   'category': 'WEIRD NEWS',
#   'short_description': 'They fled the restaurant and called the cops.',
#   'authors': 'Ed Mazza',
#   'date': Timestamp('2022-05-31 00:00:00'),
#   'score': 0.48007352810727505,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/donald-trump-white-supremacists-and-moving-forward_us_598f693fe4b0ed1f464c0b35',
#   'headline': 'Donald Trump, White Supremacists And How We Move Forward',
#   'category': 'BLACK VOICES',
#   'short_description': 'If you think that hateful events like this have nothing to do with Donald Trump, then you are delusional.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-08-12 00:00:00'),
#   'score': 0.28442293758304815,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffingtonpost.com/entry/whiteness-is-protected-even-at-its-worst_us_598f77d9e4b063e2ae05802b',
#   'headline': 'Whiteness Is Always Protected, Even At Its Worst',
#   'category': 'POLITICS',
#   'short_description': 'We have a group of white supremacists and literal Nazis who are starting fights and throwing torches, and this is somehow still only being called a protestrallymarch.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-08-12 00:00:00'),
#   'score': 0.28442293758304815,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffingtonpost.com/entry/kylie-jenner-and-pepsi-team-up-to-commodify-the-struggle_us_58e41b20e4b09deecf0e1b59',
#   'headline': 'Kendall Jenner And Pepsi Team-Up To Commodify The Struggle',
#   'category': 'BLACK VOICES',
#   'short_description': 'Wow, suddenly every societal ill is fixed. All thanks to Kendall Jenner and Pepsi.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-04-05 00:00:00'),
#   'score': 0.28442293758304815,
#   'matched_fields': 'authors'}]

# %% [markdown]
# ## Semantic Search

# %%
# %%capture
# !pip install annoy
# !sudo apt-get install libomp-dev
# !pip install faiss-cpu

# %%
from sklearn.metrics.pairwise import cosine_similarity
import faiss
from annoy import AnnoyIndex
from sentence_transformers import SentenceTransformer

# %%
path = '/content/drive/MyDrive/Colab Notebooks/news/data/'
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# search_columns = ['headline', 'short_description', 'authors']
# for col in search_columns:
#     sentences = df[col].to_list()
#     embeddings = model.encode(sentences)
#     np.savez_compressed(f'{path}{col}.npz', embeddings)
#     del sentences
#     del embeddings

# %%
class SemanticSearch():
    def __init__(self, data_path: str, model: str = "all-MiniLM-L6-v2", dimmensions: int = 384):
        self.data = df
        self.search_columns = ['headline', 'short_description', 'authors']
        self.model = SentenceTransformer(model)
        self.dimmensions = dimmensions
        self.faiss_indices = {}
        self.annoy_indices = {}

    def build(self, engine: str, embed_path: str):
        if engine == "faiss":
            for col in self.search_columns:
                embeddings = np.load(f"{embed_path}{col}.npz")['arr_0']
                index = faiss.IndexFlatL2(self.dimmensions)
                index.add(embeddings)
                self.faiss_indices[col] = index
                del embeddings
        elif engine == "annoy":
            for col in self.search_columns:
                embeddings = np.load(f"{embed_path}{col}.npz")['arr_0']
                index = AnnoyIndex(self.dimmensions, 'angular')
                for i, vec in enumerate(embeddings):
                    index.add_item(i, vec)
                index.build(20)
                self.annoy_indices[col] = index
                del embeddings
        else:
            raise ValueError('No such engine')

    def save(self, path: str):
        if self.faiss_indices:
            for col, index in self.faiss_indices.items():
                faiss.write_index(index, f"{path}_{col}.index")
        if self.annoy_indices:
            for col, index in self.annoy_indices.items():
                index.save(f"{path}_{col}.ann")

    def load(self, path: str):
        for col in self.search_columns:
            index = faiss.read_index(f"{path}_{col}.index")
            self.faiss_indices[col] = index
        for col in self.search_columns:
            index = AnnoyIndex(self.dimmensions, 'angular')
            index.load(f"{path}_{col}.ann")
            self.annoy_indices[col] = index

    def search(self, query: str, k: int = 5, engine: Optional[str] = 'both', category: Optional[str] = None, not_older_than: Optional[datetime] = None):
        query_embedding = self.model.encode(query)
        matches = []

        for col in self.search_columns:
            if engine in ["faiss", "both"] and self.faiss_indices:
                distances, indices = self.faiss_indices[col].search(query_embedding.reshape(1, -1), k)
                for idx, distance in zip(indices[0], distances[0]):
                    matches.append({'id': idx, 'score': 1 / (1 + distance), 'matched_field': col})

            if engine in ["annoy", "both"] and self.annoy_indices:
                indices, distances = self.annoy_indices[col].get_nns_by_vector(query_embedding, k, include_distances=True)
                similarities = [(2 - (dist**2)) / 2 for dist in distances]
                for idx, sim in zip(indices, similarities):
                    matches.append({'id': idx, 'score': sim, 'matched_field': col})

        filtered_results = []
        for m in matches:
            row = self.data.iloc[m['id']]
            filtered_results.append({
                'link': row['link'],
                'headline': row['headline'],
                'category': row['category'],
                'short_description': row['short_description'],
                'authors': row['authors'],
                'date': row['date'],
                'score': m['score'],
                'matched_fields': m['matched_field']
            })

        if category:
            filtered_results = [c for c in filtered_results if c['category'] in category]
        if not_older_than:
            filtered_results = [c for c in filtered_results if c['date'] >= not_older_than]

        return sorted(filtered_results, key=itemgetter('score'), reverse=True)

# %%
semantic = SemanticSearch(df)

# %%
semantic.build('faiss', embed_path=path)

# %%
semantic.build('annoy', embed_path=path)

# %%
semantic.save(path)

# %%
semantic = SemanticSearch(df)
semantic.load(path)

# %%
semantic.search("Woman Who Called Cops On Black Bird-Watcher", k=3, engine='faiss')
# Out:
# [{'link': 'https://www.huffpost.com/entry/amy-cooper-loses-discrimination-lawsuit-franklin-templeton_n_632c6463e4b09d8701bd227e',
#   'headline': 'Woman Who Called Cops On Black Bird-Watcher Loses Lawsuit Against Ex-Employer',
#   'category': 'U.S. NEWS',
#   'short_description': 'Amy Cooper accused investment firm Franklin Templeton of unfairly firing her and branding her a racist after video of the Central Park encounter went viral.',
#   'authors': 'Nina Golgowski',
#   'date': Timestamp('2022-09-22 00:00:00'),
#   'score': 0.6302691335141306,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/gwyneth-paltrow-tattoo-photos-pictures_us_5b9cbcc3e4b03a1dcc815bea',
#   'headline': 'Gwyneth Paltrow Tattoo? Star Shows Off New Body Art PHOTOS',
#   'category': 'STYLE & BEAUTY',
#   'short_description': 'Did the actress really put a bird on it?',
#   'authors': 'Rebecca Adams',
#   'date': Timestamp('2013-01-20 00:00:00'),
#   'score': 0.5292071457974201,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/spirit-awards-opening_n_6727950.html',
#   'headline': "Watch Kristen Bell  Fred Armisen Spoof 'Birdman'",
#   'category': 'ENTERTAINMENT',
#   'short_description': 'no data',
#   'authors': 'Bill Bradley',
#   'date': Timestamp('2015-02-21 00:00:00'),
#   'score': 0.5277372577329641,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/nypd-cop-saves-choking-woman-video_n_5854544.html',
#   'headline': 'WATCH Cop Pulls Over Choking Woman, Saves Her Life',
#   'category': 'GOOD NEWS',
#   'short_description': 'no data',
#   'authors': 'Ryan Grenoble',
#   'date': Timestamp('2014-09-20 00:00:00'),
#   'score': 0.5228945187883365,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.comhttp://moms.today.com/_news/2012/10/09/14301189-dad-demands-apology-from-ann-coulter-for-using-retarded-as-an-insult?lite',
#   'headline': "Dad Demands Apology From Ann Coulter For Using 'Retarded' As An Insult",
#   'category': 'PARENTING',
#   'short_description': 'Retard! Retard! Its the shrill call of a vile black bird, a call I hear coming from the treetops and from behind dark',
#   'authors': 'no data',
#   'date': Timestamp('2012-10-10 00:00:00'),
#   'score': 0.5146561458975099,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/saoirse-ronan-style-evolution_us_5a592f0fe4b04f3c55a295dd',
#   'headline': "Saoirse Ronan's Stunning Style Evolution Through The Years",
#   'category': 'STYLE',
#   'short_description': 'The "Lady Bird" star has been killing it on the red carpet these days.',
#   'authors': 'Julia Brucculieri',
#   'date': Timestamp('2018-01-19 00:00:00'),
#   'score': 0.5138730774037201,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/evolution-of-darwin-from-_b_6693458.html',
#   'headline': 'Evolution of Darwin From Thrill-Seeking to Thought-Provoking',
#   'category': 'TRAVEL',
#   'short_description': 'Its no secret Australia is a country infested with things that will kill you. Or as humorist and Australiaphile Bill Bryson put it, "If you are not stung or pronged to death in some unexpected manner, you may be fatally chomped by sharks or crocodiles."',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2015-02-24 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffingtonpost.com/entry/nautical-stripes-help-pue_b_6329142.html',
#   'headline': 'Nautical Stripes Help Puerto Rican Culture Sail Off the Island',
#   'category': 'LATINO VOICES',
#   'short_description': 'While viewing the fantastic and seemingly-endless Jean Paul Gaultier special exhibition at the National Gallery of Victoria in Melbourne, Australia in October my mind traveled back to Puerto Rico.',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2014-12-16 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffingtonpost.com/entry/just_home-_b_5568139.html',
#   'headline': 'Vacations Just Like Home, Only Better',
#   'category': 'TRAVEL',
#   'short_description': 'I started thinking about this in Maine, during a visit to the Black Point Inn. Viewing the sunset over the ocean from a sprawling porch with a glass of wine in hand was great but it was the people there who made it special.',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2014-07-24 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors'}]

# %%
semantic.search("Woman Who Called Cops On Black Bird-Watcher", engine='annoy')
# Out:
# [{'link': 'https://www.huffingtonpost.com/entry/issa-rae-insecure-black-tv-shows_us_57f2b38ee4b0c2407cdf3d96',
#   'headline': "How Issa Rae's 'Insecure' Validates, Expands On The Black Narrative",
#   'category': 'BLACK VOICES',
#   'short_description': 'She took cues from the best of black TV and weaved them into the show.',
#   'authors': 'Rahel Gebreyes',
#   'date': Timestamp('2016-10-06 00:00:00'),
#   'score': 0.49684624837342994,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/lady-bird-trailer-but-every-line-is-screamed_us_5a6c904be4b0ddb658c6cfc2',
#   'headline': "So Here's The 'Lady Bird' Trailer Except Every Line Is Screamed",
#   'category': 'ENTERTAINMENT',
#   'short_description': "You're allowed to enjoy this -- it's the weekend.",
#   'authors': 'Andy McDonald',
#   'date': Timestamp('2018-01-27 00:00:00'),
#   'score': 0.4640134996075176,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/deirdre-orozco-road-rage_n_6382738.html',
#   'headline': 'WATCH Woman Allegedly Posed As Sheriff, Rammed Other Car In Road Rage',
#   'category': 'CRIME',
#   'short_description': 'no data',
#   'authors': 'Steven Hoffer',
#   'date': Timestamp('2014-12-26 00:00:00'),
#   'score': 0.4462759286795688,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffpost.com/entry/tv-reporter-sexual-harassment-rochest_n_60fc1c5ee4b0a807eeb2534c',
#   'headline': 'TV Reporter Shares Harrowing Experience Enduring Sexual Harassment In The Field',
#   'category': 'U.S. NEWS',
#   'short_description': "The journalist highlighted what it's like for her as a Black woman facing racism and revolting unwanted advances while on the job.",
#   'authors': 'Kimberley Richards',
#   'date': Timestamp('2021-07-24 00:00:00'),
#   'score': 0.4432353663555375,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/parrot-cash-me-ousside_us_58c1840de4b0d1078ca4c150',
#   'headline': "Woman Trains Parrot To Say Birdbrained Catchphrase Cash Me Ousside'",
#   'category': 'WEIRD NEWS',
#   'short_description': '"Polly wants another meme! RAWK!"',
#   'authors': 'David Moye',
#   'date': Timestamp('2017-03-09 00:00:00'),
#   'score': 0.4424349013939306,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/samira-wiley-handmaids-tale-season-2_us_5aa168fbe4b0e9381c168625',
#   'headline': "Samira Wiley Says 'Handmaid's Tale' Season 2 Will Show Parts Of Gilead We've Never Seen",
#   'category': 'ENTERTAINMENT',
#   'short_description': "The actress opens up about filming amid the Me Too movement and addresses her past comments on the show's handling of race.",
#   'authors': 'Leigh Blickley',
#   'date': Timestamp('2018-03-09 00:00:00'),
#   'score': 0.43521104974870894,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/jenifer-lewis-a-no-holds-barred-interview-with-the_us_5a03a290e4b055de8d096a72',
#   'headline': "Jenifer Lewis A No-Holds-Barred Interview With 'The Mother Of Black Hollywood'",
#   'category': 'BLACK VOICES',
#   'short_description': 'The "Black-ish" star opens up about her new book.',
#   'authors': 'Dustin Fitzharris, ContributorJournalist in New York',
#   'date': Timestamp('2017-11-09 00:00:00'),
#   'score': 0.41802201391283234,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/the-radical-importance-of-issa-raes-insecure_us_5976241de4b0aad8e51c5bfc',
#   'headline': "The Radical Importance Of Issa Rae's 'Insecure'",
#   'category': 'BLACK VOICES',
#   'short_description': "When's the last time we got to see a black, 20-something year old woman on TV get to be so complicated?",
#   'authors': 'Zeba Blay',
#   'date': Timestamp('2017-07-24 00:00:00'),
#   'score': 0.4130155241554121,
#   'matched_fields': 'short_description'},
#  {'link': 'https://www.huffingtonpost.com/entry/jenny-yang-white-people-beverly-hills_us_57f85d4be4b068ecb5deaa52',
#   'headline': 'Asian Woman Interviews Unsuspecting White People In Fox News-Inspired Video',
#   'category': 'COMEDY',
#   'short_description': 'Jesse Watters went to Chinatown, so Jenny Yang went to Beverly Hills.',
#   'authors': 'Carla Herreria',
#   'date': Timestamp('2016-10-08 00:00:00'),
#   'score': 0.3846493735771901,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/black-voices-atlanta-spot_us_5badbba2e4b0bb1705fa9e26',
#   'headline': "Black Voices Atlanta Spotlight 'Facts of Life' Actress Kim Fields Loves The Professional Opportunities in Atlanta",
#   'category': 'BLACK VOICES',
#   'short_description': 'As the former capitol of the "Old South," Atlanta is also the same city that gave birth to the Civil Rights Movement. Today',
#   'authors': 'Patrice Peck',
#   'date': Timestamp('2012-07-15 00:00:00'),
#   'score': 0.3821045604059279,
#   'matched_fields': 'headline'},
#  {'link': 'https://www.huffingtonpost.com/entry/why-i-am-marching-on-mothers-day-for-my-son_b_7169852.html',
#   'headline': "Why I Am Marching on Mother's Day for My Son",
#   'category': 'BLACK VOICES',
#   'short_description': "It's hard for me to celebrate on Mother's Day. I feel the absence of my 23-year-old son, Sean Elijah Bell, who was killed on November 25, 2006. He was out celebrating at his own bachelor party with his friends in New York City. It was only a matter of a hours before his wedding, and I was so thrilled.",
#   'authors': 'Valerie Bell, ContributorFounder, Mothers of Never Again',
#   'date': Timestamp('2015-05-06 00:00:00'),
#   'score': 0.3515893795101874,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffingtonpost.com/entry/global-business-leadership_b_5243847.html',
#   'headline': 'Global Business Leaders to the Rescue!',
#   'category': 'BUSINESS',
#   'short_description': "Let's face it We are living in a time that is upside down economically, environmentally and psychologically. Our weakened sense of responsibility toward one another is taking us down a road marked Dead End. Time is of the essence. Hope can be on the way.",
#   'authors': 'Debbie Robins, ContributorNamed One Of The Top Leadership, Executive and Culture Coaches...',
#   'date': Timestamp('2014-05-02 00:00:00'),
#   'score': 0.328054078486268,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffpost.com/entry/america-business-economy-trump-riot-biden_n_5ff77d26c5b612d958ea6675',
#   'headline': 'The Capitol Riot Crystalizes 4 Years Of American Decline',
#   'category': 'POLITICS',
#   'short_description': "Can Biden repair Trump's damage?",
#   'authors': 'Emily Peck',
#   'date': Timestamp('2021-01-08 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffpost.com/entry/jill-biden-teach-while-first-lady_n_5fa9a639c5b64c88d403d927',
#   'headline': 'Why It Matters That Jill Biden Plans To Teach While Serving As First Lady',
#   'category': 'POLITICS',
#   'short_description': "President-elect Joe Biden's wife has said she wants to continue her work outside her White House role. That would be a first.",
#   'authors': 'Emily Peck',
#   'date': Timestamp('2020-11-10 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors'},
#  {'link': 'https://www.huffpost.com/entry/trump-crackdown-diversity-training-fascist_n_5f90b311c5b695a32fb015d7',
#   'headline': 'Trumps Crackdown On Diversity Training Is Fascist. And Terrifying.',
#   'category': 'POLITICS',
#   'short_description': 'The White House ban on anti-racism training is an authoritarian attack on free speech and already doing serious damage.',
#   'authors': 'Emily Peck',
#   'date': Timestamp('2020-10-22 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors'}]

# %% [markdown]
# ## Hybrid search

# %%
def hybrid_search(query, k=5, alpha: float = 0.5, category=None, not_older_than=None):
    """
    α = 1 - only semantic search
    α = 0 - only lexical search
    0 < α < 1 - lexical and semantic search
    """
    assert 0 <= alpha <= 1, "Alpha must be between 0 and 1."

    if alpha == 0:
        return lexical.search(query, k=k, category=category, not_older_than=not_older_than)
    elif alpha == 1:
        return semantic.search(query, k=k, category=category, not_older_than=not_older_than)
    else:
        lexical_results = lexical.search(query, k=k, category=category, not_older_than=not_older_than)
        semantic_results = semantic.search(query, k=k, category=category, not_older_than=not_older_than)

        # Adjust scores
        for item in lexical_results:
            item["adjusted_score"] = item["score"] * (1 - alpha)
            item["type"] = "lexical"

        for item in semantic_results:
            item["adjusted_score"] = item["score"] * alpha
            item["type"] = "semantic"

        # Combine results
        combined_results = lexical_results + semantic_results

        # Sort by adjusted score in descending order and remove duplicates based on 'link'
        seen_links = set()
        final_results = []
        for item in sorted(combined_results, key=lambda x: x["adjusted_score"], reverse=True):
            if item["link"] not in seen_links:
                seen_links.add(item["link"])
                final_results.append(item)

        return final_results

# %%
hybrid_search("Woman Who Called Cops On Black Bird-Watcher", alpha=0.6)
# Out:
# Split strings:   0%|          | 0/1 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'link': 'https://www.huffpost.com/entry/amy-cooper-loses-discrimination-lawsuit-franklin-templeton_n_632c6463e4b09d8701bd227e',
#   'headline': 'Woman Who Called Cops On Black Bird-Watcher Loses Lawsuit Against Ex-Employer',
#   'category': 'U.S. NEWS',
#   'short_description': 'Amy Cooper accused investment firm Franklin Templeton of unfairly firing her and branding her a racist after video of the Central Park encounter went viral.',
#   'authors': 'Nina Golgowski',
#   'date': Timestamp('2022-09-22 00:00:00'),
#   'score': 0.954927427292993,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.38197097091719723,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/gwyneth-paltrow-tattoo-photos-pictures_us_5b9cbcc3e4b03a1dcc815bea',
#   'headline': 'Gwyneth Paltrow Tattoo? Star Shows Off New Body Art PHOTOS',
#   'category': 'STYLE & BEAUTY',
#   'short_description': 'Did the actress really put a bird on it?',
#   'authors': 'Rebecca Adams',
#   'date': Timestamp('2013-01-20 00:00:00'),
#   'score': 0.5292071457974201,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.31752428747845207,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/spirit-awards-opening_n_6727950.html',
#   'headline': "Watch Kristen Bell  Fred Armisen Spoof 'Birdman'",
#   'category': 'ENTERTAINMENT',
#   'short_description': 'no data',
#   'authors': 'Bill Bradley',
#   'date': Timestamp('2015-02-21 00:00:00'),
#   'score': 0.5277372577329641,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.31664235463977847,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/nypd-cop-saves-choking-woman-video_n_5854544.html',
#   'headline': 'WATCH Cop Pulls Over Choking Woman, Saves Her Life',
#   'category': 'GOOD NEWS',
#   'short_description': 'no data',
#   'authors': 'Ryan Grenoble',
#   'date': Timestamp('2014-09-20 00:00:00'),
#   'score': 0.5228945187883365,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.3137367112730019,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/is-actress-camille-sulliv_b_6142012.html',
#   'headline': 'Is Actress Camille Sullivan of Upcoming Film the Birdwatcher Superstitious?',
#   'category': 'ENTERTAINMENT',
#   'short_description': "Let's talk about Camille Sullivan. This was a close one - just as I was going to print, a batch of Camille's new photos arrived in my mailbox. Yes! Oops. I went off on a tangent. How so not me.",
#   'authors': 'Ilana Rapp, ContributorWriter, NYCastings, "V" fanatic',
#   'date': Timestamp('2014-11-12 00:00:00'),
#   'score': 0.5186639645498965,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.3111983787299379,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.comhttp://moms.today.com/_news/2012/10/09/14301189-dad-demands-apology-from-ann-coulter-for-using-retarded-as-an-insult?lite',
#   'headline': "Dad Demands Apology From Ann Coulter For Using 'Retarded' As An Insult",
#   'category': 'PARENTING',
#   'short_description': 'Retard! Retard! Its the shrill call of a vile black bird, a call I hear coming from the treetops and from behind dark',
#   'authors': 'no data',
#   'date': Timestamp('2012-10-10 00:00:00'),
#   'score': 0.5146561458975099,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.3087936875385059,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/peacock-abduction-video_n_7024912.html',
#   'headline': 'CAUGHT ON CAMERA Suspect Bird-Naps Peacock',
#   'category': 'CRIME',
#   'short_description': 'no data',
#   'authors': 'Steven Hoffer',
#   'date': Timestamp('2015-04-08 00:00:00'),
#   'score': 0.5141143359995617,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.308468601599737,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/saoirse-ronan-style-evolution_us_5a592f0fe4b04f3c55a295dd',
#   'headline': "Saoirse Ronan's Stunning Style Evolution Through The Years",
#   'category': 'STYLE',
#   'short_description': 'The "Lady Bird" star has been killing it on the red carpet these days.',
#   'authors': 'Julia Brucculieri',
#   'date': Timestamp('2018-01-19 00:00:00'),
#   'score': 0.5138730774037201,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.30832384644223204,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/trevor-noah-second-amendment-is-not-intended-for-black-people_n_5bfe1f02e4b0f43bf2662986',
#   'headline': "Trevor Noah 'The Second Amendment Is Not Intended For Black People'",
#   'category': 'COMEDY',
#   'short_description': 'Cops are called into a situation, they see a black person and then immediately they shoot.',
#   'authors': 'Carla Baranauckas',
#   'date': Timestamp('2018-11-28 00:00:00'),
#   'score': 0.5086505868006493,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.3051903520803896,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/from-sophia-king-to-charleena-lyles-intersections_us_59657b56e4b09be68c005635',
#   'headline': 'From Charleena Lyles To Sophia King, Black Women Are Uniquely Endangered By Police',
#   'category': 'BLACK VOICES',
#   'short_description': 'A raft of highly-publicized killings reveal the unique threat Black women face from law enforcement, even when they make the call for help.',
#   'authors': 'Dr. Candice Bledsoe, ContributorDr. Candice Bledsoe is a faculty member at SMU Simmons School ...',
#   'date': Timestamp('2017-07-12 00:00:00'),
#   'score': 0.5061485837857146,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.30368915027142873,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/issa-rae-insecure-black-tv-shows_us_57f2b38ee4b0c2407cdf3d96',
#   'headline': "How Issa Rae's 'Insecure' Validates, Expands On The Black Narrative",
#   'category': 'BLACK VOICES',
#   'short_description': 'She took cues from the best of black TV and weaved them into the show.',
#   'authors': 'Rahel Gebreyes',
#   'date': Timestamp('2016-10-06 00:00:00'),
#   'score': 0.49684624837342994,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.29810774902405796,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/evolution-of-darwin-from-_b_6693458.html',
#   'headline': 'Evolution of Darwin From Thrill-Seeking to Thought-Provoking',
#   'category': 'TRAVEL',
#   'short_description': 'Its no secret Australia is a country infested with things that will kill you. Or as humorist and Australiaphile Bill Bryson put it, "If you are not stung or pronged to death in some unexpected manner, you may be fatally chomped by sharks or crocodiles."',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2015-02-24 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.2966898210369951,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/nautical-stripes-help-pue_b_6329142.html',
#   'headline': 'Nautical Stripes Help Puerto Rican Culture Sail Off the Island',
#   'category': 'LATINO VOICES',
#   'short_description': 'While viewing the fantastic and seemingly-endless Jean Paul Gaultier special exhibition at the National Gallery of Victoria in Melbourne, Australia in October my mind traveled back to Puerto Rico.',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2014-12-16 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.2966898210369951,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/just_home-_b_5568139.html',
#   'headline': 'Vacations Just Like Home, Only Better',
#   'category': 'TRAVEL',
#   'short_description': 'I started thinking about this in Maine, during a visit to the Black Point Inn. Viewing the sunset over the ocean from a sprawling porch with a glass of wine in hand was great but it was the people there who made it special.',
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2014-07-24 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.2966898210369951,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/a-century-later-the-same-_b_5575661.html',
#   'headline': 'A Century Later the Same Old Thrill',
#   'category': 'TRAVEL',
#   'short_description': "The first time I flew in an airplane, I was six. It was an Eastern Airlines flight from Miami to Newark, probably in a DC-8, but I can't say for sure.",
#   'authors': 'Christine Negroni, ContributorAuthor of the forthcoming The Crash Detectives Investigating ...',
#   'date': Timestamp('2014-07-10 00:00:00'),
#   'score': 0.4944830350616585,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.2966898210369951,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/robert-mugabe-zimbabwe-dead_n_5a19a348e4b0cee6c04ff977',
#   'headline': 'Robert Mugabe, Zimbabwes First Post-Independence Leader, Dead At 95',
#   'category': 'WORLD NEWS',
#   'short_description': 'His death comes nearly two years after he was forced to resign as president in the wake of a sudden military takeover.',
#   'authors': 'Rebecca Falconer',
#   'date': Timestamp('2019-09-06 00:00:00'),
#   'score': 0.49394766595141304,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.2963685995708478,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/lady-bird-trailer-but-every-line-is-screamed_us_5a6c904be4b0ddb658c6cfc2',
#   'headline': "So Here's The 'Lady Bird' Trailer Except Every Line Is Screamed",
#   'category': 'ENTERTAINMENT',
#   'short_description': "You're allowed to enjoy this -- it's the weekend.",
#   'authors': 'Andy McDonald',
#   'date': Timestamp('2018-01-27 00:00:00'),
#   'score': 0.4640134996075176,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.27840809976451053,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/cookout-after-cops-called-over-black-bbq_us_5af86368e4b00d7e4c1b9caf',
#   'headline': 'Massive Cookout Thrown In Park Where Cops Were Called On Black Family BBQ',
#   'category': 'BLACK VOICES',
#   'short_description': 'How Black Oakland responds to a white lady calling the cops on Black folks BBQing."',
#   'authors': 'Nina Golgowski',
#   'date': Timestamp('2018-05-13 00:00:00'),
#   'score': 0.690010834720987,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2760043338883948,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/deirdre-orozco-road-rage_n_6382738.html',
#   'headline': 'WATCH Woman Allegedly Posed As Sheriff, Rammed Other Car In Road Rage',
#   'category': 'CRIME',
#   'short_description': 'no data',
#   'authors': 'Steven Hoffer',
#   'date': Timestamp('2014-12-26 00:00:00'),
#   'score': 0.4462759286795688,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.26776555720774126,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/tv-reporter-sexual-harassment-rochest_n_60fc1c5ee4b0a807eeb2534c',
#   'headline': 'TV Reporter Shares Harrowing Experience Enduring Sexual Harassment In The Field',
#   'category': 'U.S. NEWS',
#   'short_description': "The journalist highlighted what it's like for her as a Black woman facing racism and revolting unwanted advances while on the job.",
#   'authors': 'Kimberley Richards',
#   'date': Timestamp('2021-07-24 00:00:00'),
#   'score': 0.4432353663555375,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.26594121981332247,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/parrot-cash-me-ousside_us_58c1840de4b0d1078ca4c150',
#   'headline': "Woman Trains Parrot To Say Birdbrained Catchphrase Cash Me Ousside'",
#   'category': 'WEIRD NEWS',
#   'short_description': '"Polly wants another meme! RAWK!"',
#   'authors': 'David Moye',
#   'date': Timestamp('2017-03-09 00:00:00'),
#   'score': 0.4424349013939306,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.26546094083635835,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/samira-wiley-handmaids-tale-season-2_us_5aa168fbe4b0e9381c168625',
#   'headline': "Samira Wiley Says 'Handmaid's Tale' Season 2 Will Show Parts Of Gilead We've Never Seen",
#   'category': 'ENTERTAINMENT',
#   'short_description': "The actress opens up about filming amid the Me Too movement and addresses her past comments on the show's handling of race.",
#   'authors': 'Leigh Blickley',
#   'date': Timestamp('2018-03-09 00:00:00'),
#   'score': 0.43521104974870894,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.26112662984922536,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/jenifer-lewis-a-no-holds-barred-interview-with-the_us_5a03a290e4b055de8d096a72',
#   'headline': "Jenifer Lewis A No-Holds-Barred Interview With 'The Mother Of Black Hollywood'",
#   'category': 'BLACK VOICES',
#   'short_description': 'The "Black-ish" star opens up about her new book.',
#   'authors': 'Dustin Fitzharris, ContributorJournalist in New York',
#   'date': Timestamp('2017-11-09 00:00:00'),
#   'score': 0.41802201391283234,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2508132083476994,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/the-radical-importance-of-issa-raes-insecure_us_5976241de4b0aad8e51c5bfc',
#   'headline': "The Radical Importance Of Issa Rae's 'Insecure'",
#   'category': 'BLACK VOICES',
#   'short_description': "When's the last time we got to see a black, 20-something year old woman on TV get to be so complicated?",
#   'authors': 'Zeba Blay',
#   'date': Timestamp('2017-07-24 00:00:00'),
#   'score': 0.4130155241554121,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.24780931449324725,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/jenny-yang-white-people-beverly-hills_us_57f85d4be4b068ecb5deaa52',
#   'headline': 'Asian Woman Interviews Unsuspecting White People In Fox News-Inspired Video',
#   'category': 'COMEDY',
#   'short_description': 'Jesse Watters went to Chinatown, so Jenny Yang went to Beverly Hills.',
#   'authors': 'Carla Herreria',
#   'date': Timestamp('2016-10-08 00:00:00'),
#   'score': 0.3846493735771901,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.23078962414631404,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/black-voices-atlanta-spot_us_5badbba2e4b0bb1705fa9e26',
#   'headline': "Black Voices Atlanta Spotlight 'Facts of Life' Actress Kim Fields Loves The Professional Opportunities in Atlanta",
#   'category': 'BLACK VOICES',
#   'short_description': 'As the former capitol of the "Old South," Atlanta is also the same city that gave birth to the Civil Rights Movement. Today',
#   'authors': 'Patrice Peck',
#   'date': Timestamp('2012-07-15 00:00:00'),
#   'score': 0.3821045604059279,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.22926273624355673,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/sonic-snake_n_6295a660e4b05cfc269e2615',
#   'headline': 'Sonic Workers Find An Absolute Nightmare Lurking Just Behind The Fry Machine',
#   'category': 'WEIRD NEWS',
#   'short_description': 'They fled the restaurant and called the cops.',
#   'authors': 'Ed Mazza',
#   'date': Timestamp('2022-05-31 00:00:00'),
#   'score': 0.5417715083458282,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2167086033383313,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/man-whistling-closing-time_us_5840b33de4b017f37fe3dc49',
#   'headline': "Woman Calls Cops On Man Who Won't Stop Whistling 'Closing Time'",
#   'category': 'WEIRD NEWS',
#   'short_description': '"I know who I want to take me home  I know who I want to take me home  I know who I want to take me home ... "',
#   'authors': 'David Moye',
#   'date': Timestamp('2016-12-02 00:00:00'),
#   'score': 0.5413038527806695,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.21652154111226782,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/handcuffs-arkansas-kinky-police_us_56bedc17e4b0c3c5505190ee',
#   'headline': "Couple's 'Kinky' Night In Handcuffs Ends In Real Arrest",
#   'category': 'CRIME',
#   'short_description': 'The pair lost the key and called cops, who realized there was a warrant out for the husband.',
#   'authors': 'no data',
#   'date': Timestamp('2016-02-13 00:00:00'),
#   'score': 0.5291392478377858,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2116556991351143,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/why-i-am-marching-on-mothers-day-for-my-son_b_7169852.html',
#   'headline': "Why I Am Marching on Mother's Day for My Son",
#   'category': 'BLACK VOICES',
#   'short_description': "It's hard for me to celebrate on Mother's Day. I feel the absence of my 23-year-old son, Sean Elijah Bell, who was killed on November 25, 2006. He was out celebrating at his own bachelor party with his friends in New York City. It was only a matter of a hours before his wedding, and I was so thrilled.",
#   'authors': 'Valerie Bell, ContributorFounder, Mothers of Never Again',
#   'date': Timestamp('2015-05-06 00:00:00'),
#   'score': 0.3515893795101874,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.21095362770611245,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/global-business-leadership_b_5243847.html',
#   'headline': 'Global Business Leaders to the Rescue!',
#   'category': 'BUSINESS',
#   'short_description': "Let's face it We are living in a time that is upside down economically, environmentally and psychologically. Our weakened sense of responsibility toward one another is taking us down a road marked Dead End. Time is of the essence. Hope can be on the way.",
#   'authors': 'Debbie Robins, ContributorNamed One Of The Top Leadership, Executive and Culture Coaches...',
#   'date': Timestamp('2014-05-02 00:00:00'),
#   'score': 0.328054078486268,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.1968324470917608,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/america-business-economy-trump-riot-biden_n_5ff77d26c5b612d958ea6675',
#   'headline': 'The Capitol Riot Crystalizes 4 Years Of American Decline',
#   'category': 'POLITICS',
#   'short_description': "Can Biden repair Trump's damage?",
#   'authors': 'Emily Peck',
#   'date': Timestamp('2021-01-08 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.19625854037024623,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/jill-biden-teach-while-first-lady_n_5fa9a639c5b64c88d403d927',
#   'headline': 'Why It Matters That Jill Biden Plans To Teach While Serving As First Lady',
#   'category': 'POLITICS',
#   'short_description': "President-elect Joe Biden's wife has said she wants to continue her work outside her White House role. That would be a first.",
#   'authors': 'Emily Peck',
#   'date': Timestamp('2020-11-10 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.19625854037024623,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/trump-crackdown-diversity-training-fascist_n_5f90b311c5b695a32fb015d7',
#   'headline': 'Trumps Crackdown On Diversity Training Is Fascist. And Terrifying.',
#   'category': 'POLITICS',
#   'short_description': 'The White House ban on anti-racism training is an authoritarian attack on free speech and already doing serious damage.',
#   'authors': 'Emily Peck',
#   'date': Timestamp('2020-10-22 00:00:00'),
#   'score': 0.32709756728374373,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.19625854037024623,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/drunk-girl-called-911-pretending-to-be-olivia-pope_us_56214cd1e4b0bce34700a446',
#   'headline': 'Drunk Woman Called 911 Pretending to be Olivia Pope Cops',
#   'category': 'WEIRD NEWS',
#   'short_description': 'The woman faces charges for public intoxication and misuse of the 911 system.',
#   'authors': 'Samantha Guff',
#   'date': Timestamp('2015-10-16 00:00:00'),
#   'score': 0.44222059198438907,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.17688823679375565,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/woman-allegedly-calls-cops-150-times-faces-charge_us_55c4d7fce4b0d9b743dbeb96',
#   'headline': 'Woman Allegedly Calls Cops 150 Times, Faces Charge',
#   'category': 'WEIRD NEWS',
#   'short_description': 'MACON, Ga. AP -- A central Georgia woman has been arrested after police say she called 911 scores of times over several',
#   'authors': 'no data',
#   'date': Timestamp('2015-08-07 00:00:00'),
#   'score': 0.44222059198438907,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.17688823679375565,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/patrick-quinn-ex-cop-foot-licker-sentenced_us_562abc41e4b0ec0a38949f6c',
#   'headline': "Ex-Cop Who Asked To Lick Woman's Feet Sentenced",
#   'category': 'WEIRD NEWS',
#   'short_description': 'The accused promised to let a suspect go if he could lick her feet or have her panties.',
#   'authors': 'no data',
#   'date': Timestamp('2015-10-23 00:00:00'),
#   'score': 0.42058298664575333,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.16823319465830133,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/donald-trump-white-supremacists-and-moving-forward_us_598f693fe4b0ed1f464c0b35',
#   'headline': 'Donald Trump, White Supremacists And How We Move Forward',
#   'category': 'BLACK VOICES',
#   'short_description': 'If you think that hateful events like this have nothing to do with Donald Trump, then you are delusional.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-08-12 00:00:00'),
#   'score': 0.3079906396429976,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.12319625585719905,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/whiteness-is-protected-even-at-its-worst_us_598f77d9e4b063e2ae05802b',
#   'headline': 'Whiteness Is Always Protected, Even At Its Worst',
#   'category': 'POLITICS',
#   'short_description': 'We have a group of white supremacists and literal Nazis who are starting fights and throwing torches, and this is somehow still only being called a protestrallymarch.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-08-12 00:00:00'),
#   'score': 0.3079906396429976,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.12319625585719905,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/kylie-jenner-and-pepsi-team-up-to-commodify-the-struggle_us_58e41b20e4b09deecf0e1b59',
#   'headline': 'Kendall Jenner And Pepsi Team-Up To Commodify The Struggle',
#   'category': 'BLACK VOICES',
#   'short_description': 'Wow, suddenly every societal ill is fixed. All thanks to Kendall Jenner and Pepsi.',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-04-05 00:00:00'),
#   'score': 0.3079906396429976,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.12319625585719905,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/ciara-future-and-the-degradation-of-black-women_us_58c58028e4b0a797c1d39e12',
#   'headline': 'Ciara, Future And The Degradation Of Black Women',
#   'category': 'ENTERTAINMENT',
#   'short_description': 'Here is a little backstory for those who may not know about the FutureCiaraRussell drama. Future and Ciara used to be a',
#   'authors': 'Tyler Payton, ContributorYoung black woman with a lot to say',
#   'date': Timestamp('2017-03-12 00:00:00'),
#   'score': 0.3079906396429976,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.12319625585719905,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/lessons-of-ferguson-for-the-good-of-law-enforcement_b_6943294.html',
#   'headline': 'Lessons of Ferguson For the Good of Law Enforcement',
#   'category': 'CRIME',
#   'short_description': 'Stats should never be an "outcome". The only measure of police success should be the absence of crime in a community and the ability to work with the community to achieve that goal. Period.',
#   'authors': 'Lynette Mae, ContributorRetired cop and fiction writer',
#   'date': Timestamp('2015-03-26 00:00:00'),
#   'score': 0.22992409053221596,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.0919696362128864,
#   'type': 'lexical'}]

# %%
hybrid_search("Bitcoin", alpha=0.6, not_older_than=datetime(2017,1,1))
# Out:
# Split strings:   0%|          | 0/1 [00:00<?, ?it/s]
# Stem Tokens:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# BM25S Retrieve:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'link': 'https://www.huffingtonpost.com/entry/the-bitcoin-hoax_us_5a3fd6dce4b025f99e17bb2f',
#   'headline': 'The Bitcoin Hoax',
#   'category': 'TECH',
#   'short_description': 'We should hardly be surprised that Bitcoin is on a wild speculative ridethats the essence of privatized credit creation.',
#   'authors': 'Robert Kuttner, ColumnistColumnist',
#   'date': Timestamp('2017-12-24 00:00:00'),
#   'score': 0.6098416791123972,
#   'matched_fields': 'headline',
#   'adjusted_score': 0.3659050074674383,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/tiny-towns-small-states-bet-on-bitcoin-even-as-some_us_5ac7a421e4b0150d9bfe77ba',
#   'headline': 'Tiny Towns, Small States Bet On Bitcoin Even As Some Shun Its Miners',
#   'category': 'POLITICS',
#   'short_description': 'Bitcoin enthusiasts envision a world in which the entire economy runs on blockchain technology, allowing people to buy their',
#   'authors': 'Stateline, Editorial Partner',
#   'date': Timestamp('2018-04-06 00:00:00'),
#   'score': 0.5390415677081727,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.3234249406249036,
#   'type': 'semantic'},
#  {'link': 'https://www.huffingtonpost.com/entry/the-20-funniest-tweets-from-women-this-week_us_5aa1a8cfe4b01b9b0a39881c',
#   'headline': 'The 20 Funniest Tweets From Women This Week',
#   'category': 'WOMEN',
#   'short_description': 'How to use bitcoins, Sam Nunberg jokes and more.',
#   'authors': 'Hollis Miller',
#   'date': Timestamp('2018-03-09 00:00:00'),
#   'score': 0.5342433238276588,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.3205459942965953,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/libra-facebook-cryptocurrency-details_l_5d097144e4b06ad4d257e35c',
#   'headline': "Everything You Need To Know About Libra, Facebook's New Cryptocurrency",
#   'category': 'MONEY',
#   'short_description': "The tech giant is entering the cryptocurrency space, but don't expect Libra to be another Bitcoin.",
#   'authors': 'Casey Bond',
#   'date': Timestamp('2019-06-20 00:00:00'),
#   'score': 0.5703735403935672,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2281494161574269,
#   'type': 'lexical'},
#  {'link': 'https://www.huffingtonpost.com/entry/russian-hackers-liberal-groups-pennsylvania-democrats_us_58be0aede4b09ab537d6491a',
#   'headline': 'Hackers Shaking Down Pennsylvania Democrats and U.S. Progressive Groups',
#   'category': 'TECH',
#   'short_description': 'Computers are infected with ransomware and attackers seek Bitcoin payoffs. Signs again point to Russia.',
#   'authors': 'Mary Papenfuss',
#   'date': Timestamp('2017-03-07 00:00:00'),
#   'score': 0.5423270343458915,
#   'matched_fields': 'short_description',
#   'adjusted_score': 0.2169308137383566,
#   'type': 'lexical'},
#  {'link': 'https://www.huffpost.com/entry/aakayla-gunn-delivers-baby-sister_l_60dc8872e4b0b9e497e15b49',
#   'headline': '9-Year-Old Girl Helps Deliver Baby Sister In Missouri Home',
#   'category': 'PARENTING',
#   'short_description': 'When Angelica Gunn started having contractions more than a week before her due date, her daughter, Aakayla, stepped in to help.',
#   'authors': 'no data',
#   'date': Timestamp('2021-06-30 00:00:00'),
#   'score': 0.2491371236626989,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.14948227419761934,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/san-diego-zoo-elephant-habitat-arrest_n_6055cd94c5b6bd95117d2341',
#   'headline': 'Father Accused Of Taking 2-Year-Old Into Elephant Habitat At San Diego Zoo',
#   'category': 'U.S. NEWS',
#   'short_description': 'The 25-year-old dropped his young daughter when the elephant seemed like it wanted to charge at them, said police.',
#   'authors': 'no data',
#   'date': Timestamp('2021-03-20 00:00:00'),
#   'score': 0.2491371236626989,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.14948227419761934,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/india-farmer-protests-highway_n_601ec498c5b689330e2fc30b',
#   'headline': 'Thousands Of Farmers In India Blockade Highways Protesting New Agricultural Laws',
#   'category': 'WORLD NEWS',
#   'short_description': 'People blocked highways around the country in the fight for the repeal of laws they say will put farmers at the mercy of big corporations.',
#   'authors': 'no data',
#   'date': Timestamp('2021-02-06 00:00:00'),
#   'score': 0.2491371236626989,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.14948227419761934,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/kevin-spacey-accuser-drops-lawsuit_n_5d1f8292e4b01b83473610f3',
#   'headline': 'Kevin Spacey Accuser Drops Lawsuit Against Actor',
#   'category': 'U.S. NEWS',
#   'short_description': 'Spacey still faces a criminal charge.',
#   'authors': 'no data',
#   'date': Timestamp('2019-07-05 00:00:00'),
#   'score': 0.2491371236626989,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.14948227419761934,
#   'type': 'semantic'},
#  {'link': 'https://www.huffpost.com/entry/austrian-chancellor-sebastian-kurz-ousted-no-confidence-vote_n_5cec0095e4b00356fc25a8ae',
#   'headline': 'Austrian Chancellor Sebastian Kurz Ousted In No-Confidence Vote',
#   'category': 'WORLD NEWS',
#   'short_description': 'A party leader tied to Kurz had appeared to offer favors to a Russian investor.',
#   'authors': 'no data',
#   'date': Timestamp('2019-05-27 00:00:00'),
#   'score': 0.2491371236626989,
#   'matched_fields': 'authors',
#   'adjusted_score': 0.14948227419761934,
#   'type': 'semantic'}]
